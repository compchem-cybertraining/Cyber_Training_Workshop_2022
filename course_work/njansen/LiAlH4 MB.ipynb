# %% [markdown]
# # Running the nonadiabatic molecular dynamics (NA-MD)
#
# In this tutorial, we perform NA-MD using the NACs computed in [step3](../../8_step3_cp2k/2_xTB). After the dynamic is done, we will fit the data using a stretched-compressed exponential function. We only do the dynamics for the NACs computed for the system in the xTB framework. The reason is that doing the NA-MD for the other system we considered with DFT, the rutile-$TiO_2$ unit cell, is exactly the same as below and you just need to modify some parameters as is explained in the [README.md](README.md) file.
#
# ## Table of contents
# <a name="toc"></a>
# 1. [Importing needed libraries](#import)
# 2. [Overview of required files](#required_files)
# 3. [Defining the functions and variables](#def_fun_var)
# 4. [Run the dynamics](#run_dyn)
# 5. [Decoherence times](#deco_times)
# 6. [Fitting data](#fit_data)
#
# ### A. Learning objectives
#
# * To be able to run the NA-MD using Libra
# * To be able to compute the decoherence times
# * To be able to compute the average NA-MD timescales
#
# ### B. Use cases
#
# * [Run the dynamics](#run_dyn)
# * [Decoherence times](#deco_times)
# * [Fitting data](#fit_data)
#
#
# ### C. Functions
#
# - `libra_py`
#   - `data_conv`
#   - `data_stat`
#   - `data_outs`
#   - `data_read`
#   - `workflows`
#     - `nbra`
#       - [`step4`](#run_dyn)
#         - [`namd_workflow`](#run_dyn)
#       - [`decoherence_times`](#deco_times)
#         - [`decoherence_times`](#deco_times)
#   - `units`
#     - `fs2au`

# %% [markdown]
# ## 1. Importing needed libraries <a name="import"></a>
# [Back to TOC](#toc)
#
# Since the data are stored in sparse format using `scipy.sparse` library, we need to load this library to read them. Import `numpy`, `scipy.sparse`, `data_conv`, `data_outs`, `data_stat`, `data_io`, `units`, and `step4` modules and also the `ann` for doing the NA-MD using artificial neural netwrok (we do not cover this in here). Also, `multiprocessing` library will be needed to simultaneously run the NA-MD in different batches.
# The `scipy.optimize.curve_fit` will be used to fit the data and plot them using `matplotlib`.

# %%
import os
import sys
import math
import time
import glob 

import multiprocessing as mp
import numpy as np
import scipy.sparse as sp
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
# %matplotlib inline

from liblibra_core import *
import util.libutil as comn
from libra_py import units as units
from libra_py import data_conv, data_stat, data_outs, data_read
import libra_py.workflows.nbra.decoherence_times as decoherence_times
import libra_py.workflows.nbra.step4 as step4
import libra_py.workflows.nbra.ann as ann
# Out:
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<int, std::allocator<int> >, std::allocator<std::vector<int, std::allocator<int> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<float, std::allocator<float> >, std::allocator<std::vector<float, std::allocator<float> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<double, std::allocator<double> >, std::allocator<std::vector<double, std::allocator<double> > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > > already registered; second conversion method ignored.
#   return f(*args, **kwds)
# /projects/academic/cyberwksp21/Software/Conda/Miniconda3/envs/libra/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: to-Python converter for boost::python::detail::container_element<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, unsigned long, boost::python::detail::final_vector_derived_policies<std::vector<std::vector<std::complex<double>, std::allocator<std::complex<double> > >, std::allocator<std::vector<std::complex<double>, std::allocator<std::complex<double> > > > >, false> > already registered; second conversion method ignored.
#   return f(*args, **kwds)

# %% [markdown]
# ## 2. Overview of required files <a name="required_files"></a>
# [Back to TOC](#toc)
#
# The only files that we need are the NACs obtained in [this tutorial](../../8_step3_cp2k/2_xTB/res-mixed-basis).
#
# The `inputs.tar.bz2` archive is the `data.tar.bz2` archive from that tutorial.
#
# We only need to unpack it:
#
#     tar -xjf inputs.tar.bz2

# %% [markdown]
# ## 3. Defining the functions and variables <a name="def_fun_var"></a>
# [Back to TOC](#toc)
#
# The helper functions are used in here. We will set the parameters in here. The list of all parameters are completely explained in the [README.md](README.md) file.

# %%
class tmp:
    pass


#obj = tmp()
#obj.basis_transform = CMATRIX(2,2)
#obj.basis_transform.identity()


def compute_model_nbra_direct_global(q, params, full_id):
    """   
    Read in the vibronic Hamiltonians along the trajectories    

    Args: 
        q ( MATRIX(1,1) ): coordinates of the particle, ndof, but they do not really affect anything
        params ( dictionary ): model parameters

            * **params["timestep"]** ( int ):  [ index of the file to read ]
            * **params["prefix"]**   ( string ):  [ the directory where the hdf5 file is located ]
            * **params["filename"]** ( string ):  [ the name of the HDF5 file ]
        
    Returns:       
        PyObject: obj, with the members:

            * obj.hvib_adi ( CMATRIX(n,n) ): adiabatic vibronic Hamiltonian 
            
    """

    timestep = params["timestep"]
    nadi = params["nstates"]

    #=========== Basis transform, if available =====
    basis_transform = CMATRIX(nadi, nadi)
    basis_transform.identity()

    #========= Time-overlap matrices ===================
    time_overlap_adi = CMATRIX(nadi, nadi)
    time_overlap_adi.identity()

    obj = tmp()
    obj.ham_adi = params["HADI"][timestep]
    obj.nac_adi = params["NAC"][timestep]
    obj.hvib_adi = params["HVIB"][timestep]
    obj.basis_transform = basis_transform
    obj.time_overlap_adi = params["ST"][timestep]

    return obj




def compute_model(q, params, full_id):
    model = params["model"]
    res = None

    if model==1:
        pass
    elif model==2:
        #res = ham.compute_model_nbra_2state_direct(q, params, full_id)        
        res = compute_model_nbra_direct_global(q, params, full_id)
    elif model==3:
        res = ann.compute_model_nbra_ann(q, params, full_id)
        #res.time_overlap_adi = ST[ params["timestep"] ]

    return res



#if __name__ == '__main__':

def run_dynamics(case, what):



    if case=="direct" and what in [0, 2] :
        os.system("mkdir namd_regular")
    elif case=="ann" and what in [0, 2]:
        os.system("mkdir namd_ann")


    nthreads = 8
    methods = {0:"FSSH", 1:"IDA", 2:"mSDM", 3:"DISH", 21:"mSDM2", 31:"DISH2" }
    init_states = [10]
    tsh_methods = [0,1]#, 1]
    batches = list(range(4))





    #================== SET UP THE DYNAMICS AND DISTRIBUTED COMPUTING SCHEME  ===============                      

    rnd = Random()

    rates = None
    gaps = None

    params_common = { "path_to_res_files": os.getcwd()+'/res-mb-sd-DFT', "is_sparse": True,
                      "Hvib_re_prefix": 'Hvib_ci_', "Hvib_re_suffix": '_re',
                      "Hvib_im_prefix": 'Hvib_ci_', "Hvib_im_suffix": '_im', "istep": 1200,
                      "St_re_prefix": 'St_ci_', "St_re_suffix": '_re',
                      "nsteps": 797, "dt":1*units.fs2au, "is_parallel": True,
                      "ntraj":100, "x0":[-4.0], "p0":[4.0], "masses":[2000.0], "k":[0.01],
                      "nstates":10, "istate":[1, 0],
                      "which_adi_states":range(10), "which_dia_states":range(10),
                      "rep_ham":1, "tsh_method":0, "force_method":0, "nac_update_method":0,
                      "hop_acceptance_algo":31, "momenta_rescaling_algo":0,
                      "time_overlap_method":1, "mem_output_level":-1,  "txt_output_level":-1, "txt2_output_level":3,
                      "properties_to_save": ['timestep', 'time', 'SH_pop', 'SH_pop_raw'],
                      "state_tracking_algo":0, "convergence":0,  "max_number_attempts":100,
                      "do_phase_correction":0,
                      "min_probability_reordering":0.01, "decoherence_algo":0, "Temperature": 300.0,
                      "isNBRA":1
                    }


    #=========================== DIRECT ==============================

    if case == "direct":

        dyn_params = dict(params_common)
        dyn_params.update({ "dir_prefix":"namd_regular" })
        ham_rep, is_nbra = 1, 1


        if what in [0, 2]:
            model_params_direct = {"model":2, "filename":None}
            HADI, HVIB, NAC, ST, nstates = data_read.get_all_data(params_common) #["nsteps"],  istep=0, nstates = 5)
            params_common["nstates"] = nstates
            dyn_params["nstates"] = nstates
            model_params_direct["nstates"] = nstates
            model_params_direct["istep"] = params_common["istep"]
            model_params_direct["HVIB"] = HVIB
            model_params_direct["HADI"] = HADI
            model_params_direct["NAC"] = NAC
            model_params_direct["ST"] = ST
            print(model_params_direct, 'Done with reading the files... Going to step4.')
            tau, rates = decoherence_times.decoherence_times_ave([HVIB], [0], params_common['nsteps'], 0)
            dE         = decoherence_times.energy_gaps_ave(      [HVIB], [0], params_common['nsteps'])
            avg_deco   = tau * units.au2fs
            avg_deco = data_conv.MATRIX2nparray(avg_deco)
            for i in range(len(avg_deco)):
                avg_deco[i][i] = 0
            np.savetxt('average_decoherence_mb.txt', avg_deco.real)

            step4.namd_workflow(dyn_params, compute_model, model_params_direct, rnd, nthreads,
                                methods, init_states, tsh_methods, batches, "fork", dyn_params["is_parallel"], ham_rep, is_nbra)

        if what in [1, 2]:
            step4.nice_plots(dyn_params, init_states, tsh_methods, methods, batches, fig_label="Direct NA-MD", txt_type=1)

    #=========================== ANN =================================
    elif case == "ann":

        dyn_params = dict(params_common)
        dyn_params.update({ "dir_prefix":"namd_ann" })
        ham_rep, is_nbra = 1, 1

        if what in [0, 2]:

            model_params_ann = {"model":3, "nstates":5, "filename":None, "istep":0, "dt":1.0*units.fs2au, "timestep":0 }
            ann.load_ann_and_parameters(model_params_ann, nstates=5, prefix="./")
            print(model_params_ann)

            step4.namd_workflow(dyn_params, compute_model, model_params_ann, rnd, nthreads,
                                methods, init_states, tsh_methods, batches, "fork", dyn_params["is_parallel"], ham_rep, is_nbra)

        if what in [1, 2]:
            step4.nice_plots(dyn_params, init_states, tsh_methods, methods, batches, fig_label="Ann NA-MD", txt_type=1)

# %% [markdown]
# ## 4. Run the dynamics <a name="run_dyn"></a>
# [Back to TOC](#toc)
#
# Run the dynamics using this line:
#
# The secont argument `2` means we want to run calculations AND plot the results.
#
# In general:
#
# - 0 - only compute the dynamics
# - 1 - only plot the results (if the results from the dynamics are present)
# - 2 - both compute the dynamics AND plot the results

# %%
run_dynamics("direct", 2)
# Out:
# Reading the data of step 1200
# Reading the data of step 1201
# Reading the data of step 1202
# Reading the data of step 1203
# Reading the data of step 1204
# Reading the data of step 1205
# Reading the data of step 1206
# Reading the data of step 1207
# Reading the data of step 1208
# Reading the data of step 1209
# Reading the data of step 1210
# Reading the data of step 1211
# Reading the data of step 1212
# Reading the data of step 1213
# Reading the data of step 1214
# Reading the data of step 1215
# Reading the data of step 1216
# Reading the data of step 1217
# Reading the data of step 1218
# Reading the data of step 1219
# Reading the data of step 1220
# Reading the data of step 1221
# Reading the data of step 1222
# Reading the data of step 1223
# Reading the data of step 1224
# Reading the data of step 1225
# Reading the data of step 1226
# Reading the data of step 1227
# Reading the data of step 1228
# Reading the data of step 1229
# Reading the data of step 1230
# Reading the data of step 1231
# Reading the data of step 1232
# Reading the data of step 1233
# Reading the data of step 1234
# Reading the data of step 1235
# Reading the data of step 1236
# Reading the data of step 1237
# Reading the data of step 1238
# Reading the data of step 1239
# Reading the data of step 1240
# Reading the data of step 1241
# Reading the data of step 1242
# Reading the data of step 1243
# Reading the data of step 1244
# Reading the data of step 1245
# Reading the data of step 1246
# Reading the data of step 1247
# Reading the data of step 1248
# Reading the data of step 1249
# Reading the data of step 1250
# Reading the data of step 1251
# Reading the data of step 1252
# Reading the data of step 1253
# Reading the data of step 1254
# Reading the data of step 1255
# Reading the data of step 1256
# Reading the data of step 1257
# Reading the data of step 1258
# Reading the data of step 1259
# Reading the data of step 1260
# Reading the data of step 1261
# Reading the data of step 1262
# Reading the data of step 1263
# Reading the data of step 1264
# Reading the data of step 1265
# Reading the data of step 1266
# Reading the data of step 1267
# Reading the data of step 1268
# Reading the data of step 1269
# Reading the data of step 1270
# Reading the data of step 1271
# Reading the data of step 1272
# Reading the data of step 1273
# Reading the data of step 1274
# Reading the data of step 1275
# Reading the data of step 1276
# Reading the data of step 1277
# Reading the data of step 1278
# Reading the data of step 1279
# Reading the data of step 1280
# Reading the data of step 1281
# Reading the data of step 1282
# Reading the data of step 1283
# Reading the data of step 1284
# Reading the data of step 1285
# Reading the data of step 1286
# Reading the data of step 1287
# Reading the data of step 1288
# Reading the data of step 1289
# Reading the data of step 1290
# Reading the data of step 1291
# Reading the data of step 1292
# Reading the data of step 1293
# Reading the data of step 1294
# Reading the data of step 1295
# Reading the data of step 1296
# Reading the data of step 1297
# Reading the data of step 1298
# Reading the data of step 1299
# Reading the data of step 1300
# Reading the data of step 1301
# Reading the data of step 1302
# Reading the data of step 1303
# Reading the data of step 1304
# Reading the data of step 1305
# Reading the data of step 1306
# Reading the data of step 1307
# Reading the data of step 1308
# Reading the data of step 1309
# Reading the data of step 1310
# Reading the data of step 1311
# Reading the data of step 1312
# Reading the data of step 1313
# Reading the data of step 1314
# Reading the data of step 1315
# Reading the data of step 1316
# Reading the data of step 1317
# Reading the data of step 1318
# Reading the data of step 1319
# Reading the data of step 1320
# Reading the data of step 1321
# Reading the data of step 1322
# Reading the data of step 1323
# Reading the data of step 1324
# Reading the data of step 1325
# Reading the data of step 1326
# Reading the data of step 1327
# Reading the data of step 1328
# Reading the data of step 1329
# Reading the data of step 1330
# Reading the data of step 1331
# Reading the data of step 1332
# Reading the data of step 1333
# Reading the data of step 1334
# Reading the data of step 1335
# Reading the data of step 1336
# Reading the data of step 1337
# Reading the data of step 1338
# Reading the data of step 1339
# Reading the data of step 1340
# Reading the data of step 1341
# Reading the data of step 1342
# Reading the data of step 1343
# Reading the data of step 1344
# Reading the data of step 1345
# Reading the data of step 1346
# Reading the data of step 1347
# Reading the data of step 1348
# Reading the data of step 1349
# Reading the data of step 1350
# Reading the data of step 1351
# Reading the data of step 1352
# Reading the data of step 1353
# Reading the data of step 1354
# Reading the data of step 1355
# Reading the data of step 1356
# Reading the data of step 1357
# Reading the data of step 1358
# Reading the data of step 1359
# Reading the data of step 1360
# Reading the data of step 1361
# Reading the data of step 1362
# Reading the data of step 1363
# Reading the data of step 1364
# Reading the data of step 1365
# Reading the data of step 1366
# Reading the data of step 1367
# Reading the data of step 1368
# Reading the data of step 1369
# Reading the data of step 1370
# Reading the data of step 1371
# Reading the data of step 1372
# Reading the data of step 1373
# Reading the data of step 1374
# Reading the data of step 1375
# Reading the data of step 1376
# Reading the data of step 1377
# Reading the data of step 1378
# Reading the data of step 1379
# Reading the data of step 1380
# Reading the data of step 1381
# Reading the data of step 1382
# Reading the data of step 1383
# Reading the data of step 1384
# Reading the data of step 1385
# Reading the data of step 1386
# Reading the data of step 1387
# Reading the data of step 1388
# Reading the data of step 1389
# Reading the data of step 1390
# Reading the data of step 1391
# Reading the data of step 1392
# Reading the data of step 1393
# Reading the data of step 1394
# Reading the data of step 1395
# Reading the data of step 1396
# Reading the data of step 1397
# Reading the data of step 1398
# Reading the data of step 1399
# Reading the data of step 1400
# Reading the data of step 1401
# Reading the data of step 1402
# Reading the data of step 1403
# Reading the data of step 1404
# Reading the data of step 1405
# Reading the data of step 1406
# Reading the data of step 1407
# Reading the data of step 1408
# Reading the data of step 1409
# Reading the data of step 1410
# Reading the data of step 1411
# Reading the data of step 1412
# Reading the data of step 1413
# Reading the data of step 1414
# Reading the data of step 1415
# Reading the data of step 1416
# Reading the data of step 1417
# Reading the data of step 1418
# Reading the data of step 1419
# Reading the data of step 1420
# Reading the data of step 1421
# Reading the data of step 1422
# Reading the data of step 1423
# Reading the data of step 1424
# Reading the data of step 1425
# Reading the data of step 1426
# Reading the data of step 1427
# Reading the data of step 1428
# Reading the data of step 1429
# Reading the data of step 1430
# Reading the data of step 1431
# Reading the data of step 1432
# Reading the data of step 1433
# Reading the data of step 1434
# Reading the data of step 1435
# Reading the data of step 1436
# Reading the data of step 1437
# Reading the data of step 1438
# Reading the data of step 1439
# Reading the data of step 1440
# Reading the data of step 1441
# Reading the data of step 1442
# Reading the data of step 1443
# Reading the data of step 1444
# Reading the data of step 1445
# Reading the data of step 1446
# Reading the data of step 1447
# Reading the data of step 1448
# Reading the data of step 1449
# Reading the data of step 1450
# Reading the data of step 1451
# Reading the data of step 1452
# Reading the data of step 1453
# Reading the data of step 1454
# Reading the data of step 1455
# Reading the data of step 1456
# Reading the data of step 1457
# Reading the data of step 1458
# Reading the data of step 1459
# Reading the data of step 1460
# Reading the data of step 1461
# Reading the data of step 1462
# Reading the data of step 1463
# Reading the data of step 1464
# Reading the data of step 1465
# Reading the data of step 1466
# Reading the data of step 1467
# Reading the data of step 1468
# Reading the data of step 1469
# Reading the data of step 1470
# Reading the data of step 1471
# Reading the data of step 1472
# Reading the data of step 1473
# Reading the data of step 1474
# Reading the data of step 1475
# Reading the data of step 1476
# Reading the data of step 1477
# Reading the data of step 1478
# Reading the data of step 1479
# Reading the data of step 1480
# Reading the data of step 1481
# Reading the data of step 1482
# Reading the data of step 1483
# Reading the data of step 1484
# Reading the data of step 1485
# Reading the data of step 1486
# Reading the data of step 1487
# Reading the data of step 1488
# Reading the data of step 1489
# Reading the data of step 1490
# Reading the data of step 1491
# Reading the data of step 1492
# Reading the data of step 1493
# Reading the data of step 1494
# Reading the data of step 1495
# Reading the data of step 1496
# Reading the data of step 1497
# Reading the data of step 1498
# Reading the data of step 1499
# Reading the data of step 1500
# Reading the data of step 1501
# Reading the data of step 1502
# Reading the data of step 1503
# Reading the data of step 1504
# Reading the data of step 1505
# Reading the data of step 1506
# Reading the data of step 1507
# Reading the data of step 1508
# Reading the data of step 1509
# Reading the data of step 1510
# Reading the data of step 1511
# Reading the data of step 1512
# Reading the data of step 1513
# Reading the data of step 1514
# Reading the data of step 1515
# Reading the data of step 1516
# Reading the data of step 1517
# Reading the data of step 1518
# Reading the data of step 1519
# Reading the data of step 1520
# Reading the data of step 1521
# Reading the data of step 1522
# Reading the data of step 1523
# Reading the data of step 1524
# Reading the data of step 1525
# Reading the data of step 1526
# Reading the data of step 1527
# Reading the data of step 1528
# Reading the data of step 1529
# Reading the data of step 1530
# Reading the data of step 1531
# Reading the data of step 1532
# Reading the data of step 1533
# Reading the data of step 1534
# Reading the data of step 1535
# Reading the data of step 1536
# Reading the data of step 1537
# Reading the data of step 1538
# Reading the data of step 1539
# Reading the data of step 1540
# Reading the data of step 1541
# Reading the data of step 1542
# Reading the data of step 1543
# Reading the data of step 1544
# Reading the data of step 1545
# Reading the data of step 1546
# Reading the data of step 1547
# Reading the data of step 1548
# Reading the data of step 1549
# Reading the data of step 1550
# Reading the data of step 1551
# Reading the data of step 1552
# Reading the data of step 1553
# Reading the data of step 1554
# Reading the data of step 1555
# Reading the data of step 1556
# Reading the data of step 1557
# Reading the data of step 1558
# Reading the data of step 1559
# Reading the data of step 1560
# Reading the data of step 1561
# Reading the data of step 1562
# Reading the data of step 1563
# Reading the data of step 1564
# Reading the data of step 1565
# Reading the data of step 1566
# Reading the data of step 1567
# Reading the data of step 1568
# Reading the data of step 1569
# Reading the data of step 1570
# Reading the data of step 1571
# Reading the data of step 1572
# Reading the data of step 1573
# Reading the data of step 1574
# Reading the data of step 1575
# Reading the data of step 1576
# Reading the data of step 1577
# Reading the data of step 1578
# Reading the data of step 1579
# Reading the data of step 1580
# Reading the data of step 1581
# Reading the data of step 1582
# Reading the data of step 1583
# Reading the data of step 1584
# Reading the data of step 1585
# Reading the data of step 1586
# Reading the data of step 1587
# Reading the data of step 1588
# Reading the data of step 1589
# Reading the data of step 1590
# Reading the data of step 1591
# Reading the data of step 1592
# Reading the data of step 1593
# Reading the data of step 1594
# Reading the data of step 1595
# Reading the data of step 1596
# Reading the data of step 1597
# Reading the data of step 1598
# Reading the data of step 1599
# Reading the data of step 1600
# Reading the data of step 1601
# Reading the data of step 1602
# Reading the data of step 1603
# Reading the data of step 1604
# Reading the data of step 1605
# Reading the data of step 1606
# Reading the data of step 1607
# Reading the data of step 1608
# Reading the data of step 1609
# Reading the data of step 1610
# Reading the data of step 1611
# Reading the data of step 1612
# Reading the data of step 1613
# Reading the data of step 1614
# Reading the data of step 1615
# Reading the data of step 1616
# Reading the data of step 1617
# Reading the data of step 1618
# Reading the data of step 1619
# Reading the data of step 1620
# Reading the data of step 1621
# Reading the data of step 1622
# Reading the data of step 1623
# Reading the data of step 1624
# Reading the data of step 1625
# Reading the data of step 1626
# Reading the data of step 1627
# Reading the data of step 1628
# Reading the data of step 1629
# Reading the data of step 1630
# Reading the data of step 1631
# Reading the data of step 1632
# Reading the data of step 1633
# Reading the data of step 1634
# Reading the data of step 1635
# Reading the data of step 1636
# Reading the data of step 1637
# Reading the data of step 1638
# Reading the data of step 1639
# Reading the data of step 1640
# Reading the data of step 1641
# Reading the data of step 1642
# Reading the data of step 1643
# Reading the data of step 1644
# Reading the data of step 1645
# Reading the data of step 1646
# Reading the data of step 1647
# Reading the data of step 1648
# Reading the data of step 1649
# Reading the data of step 1650
# Reading the data of step 1651
# Reading the data of step 1652
# Reading the data of step 1653
# Reading the data of step 1654
# Reading the data of step 1655
# Reading the data of step 1656
# Reading the data of step 1657
# Reading the data of step 1658
# Reading the data of step 1659
# Reading the data of step 1660
# Reading the data of step 1661
# Reading the data of step 1662
# Reading the data of step 1663
# Reading the data of step 1664
# Reading the data of step 1665
# Reading the data of step 1666
# Reading the data of step 1667
# Reading the data of step 1668
# Reading the data of step 1669
# Reading the data of step 1670
# Reading the data of step 1671
# Reading the data of step 1672
# Reading the data of step 1673
# Reading the data of step 1674
# Reading the data of step 1675
# Reading the data of step 1676
# Reading the data of step 1677
# Reading the data of step 1678
# Reading the data of step 1679
# Reading the data of step 1680
# Reading the data of step 1681
# Reading the data of step 1682
# Reading the data of step 1683
# Reading the data of step 1684
# Reading the data of step 1685
# Reading the data of step 1686
# Reading the data of step 1687
# Reading the data of step 1688
# Reading the data of step 1689
# Reading the data of step 1690
# Reading the data of step 1691
# Reading the data of step 1692
# Reading the data of step 1693
# Reading the data of step 1694
# Reading the data of step 1695
# Reading the data of step 1696
# Reading the data of step 1697
# Reading the data of step 1698
# Reading the data of step 1699
# Reading the data of step 1700
# Reading the data of step 1701
# Reading the data of step 1702
# Reading the data of step 1703
# Reading the data of step 1704
# Reading the data of step 1705
# Reading the data of step 1706
# Reading the data of step 1707
# Reading the data of step 1708
# Reading the data of step 1709
# Reading the data of step 1710
# Reading the data of step 1711
# Reading the data of step 1712
# Reading the data of step 1713
# Reading the data of step 1714
# Reading the data of step 1715
# Reading the data of step 1716
# Reading the data of step 1717
# Reading the data of step 1718
# Reading the data of step 1719
# Reading the data of step 1720
# Reading the data of step 1721
# Reading the data of step 1722
# Reading the data of step 1723
# Reading the data of step 1724
# Reading the data of step 1725
# Reading the data of step 1726
# Reading the data of step 1727
# Reading the data of step 1728
# Reading the data of step 1729
# Reading the data of step 1730
# Reading the data of step 1731
# Reading the data of step 1732
# Reading the data of step 1733
# Reading the data of step 1734
# Reading the data of step 1735
# Reading the data of step 1736
# Reading the data of step 1737
# Reading the data of step 1738
# Reading the data of step 1739
# Reading the data of step 1740
# Reading the data of step 1741
# Reading the data of step 1742
# Reading the data of step 1743
# Reading the data of step 1744
# Reading the data of step 1745
# Reading the data of step 1746
# Reading the data of step 1747
# Reading the data of step 1748
# Reading the data of step 1749
# Reading the data of step 1750
# Reading the data of step 1751
# Reading the data of step 1752
# Reading the data of step 1753
# Reading the data of step 1754
# Reading the data of step 1755
# Reading the data of step 1756
# Reading the data of step 1757
# Reading the data of step 1758
# Reading the data of step 1759
# Reading the data of step 1760
# Reading the data of step 1761
# Reading the data of step 1762
# Reading the data of step 1763
# Reading the data of step 1764
# Reading the data of step 1765
# Reading the data of step 1766
# Reading the data of step 1767
# Reading the data of step 1768
# Reading the data of step 1769
# Reading the data of step 1770
# Reading the data of step 1771
# Reading the data of step 1772
# Reading the data of step 1773
# Reading the data of step 1774
# Reading the data of step 1775
# Reading the data of step 1776
# Reading the data of step 1777
# Reading the data of step 1778
# Reading the data of step 1779
# Reading the data of step 1780
# Reading the data of step 1781
# Reading the data of step 1782
# Reading the data of step 1783
# Reading the data of step 1784
# Reading the data of step 1785
# Reading the data of step 1786
# Reading the data of step 1787
# Reading the data of step 1788
# Reading the data of step 1789
# Reading the data of step 1790
# Reading the data of step 1791
# Reading the data of step 1792
# Reading the data of step 1793
# Reading the data of step 1794
# Reading the data of step 1795
# Reading the data of step 1796
# Reading the data of step 1797
# Reading the data of step 1798
# Reading the data of step 1799
# Reading the data of step 1800
# Reading the data of step 1801
# Reading the data of step 1802
# Reading the data of step 1803
# Reading the data of step 1804
# Reading the data of step 1805
# Reading the data of step 1806
# Reading the data of step 1807
# Reading the data of step 1808
# Reading the data of step 1809
# Reading the data of step 1810
# Reading the data of step 1811
# Reading the data of step 1812
# Reading the data of step 1813
# Reading the data of step 1814
# Reading the data of step 1815
# Reading the data of step 1816
# Reading the data of step 1817
# Reading the data of step 1818
# Reading the data of step 1819
# Reading the data of step 1820
# Reading the data of step 1821
# Reading the data of step 1822
# Reading the data of step 1823
# Reading the data of step 1824
# Reading the data of step 1825
# Reading the data of step 1826
# Reading the data of step 1827
# Reading the data of step 1828
# Reading the data of step 1829
# Reading the data of step 1830
# Reading the data of step 1831
# Reading the data of step 1832
# Reading the data of step 1833
# Reading the data of step 1834
# Reading the data of step 1835
# Reading the data of step 1836
# Reading the data of step 1837
# Reading the data of step 1838
# Reading the data of step 1839
# Reading the data of step 1840
# Reading the data of step 1841
# Reading the data of step 1842
# Reading the data of step 1843
# Reading the data of step 1844
# Reading the data of step 1845
# Reading the data of step 1846
# Reading the data of step 1847
# Reading the data of step 1848
# Reading the data of step 1849
# Reading the data of step 1850
# Reading the data of step 1851
# Reading the data of step 1852
# Reading the data of step 1853
# Reading the data of step 1854
# Reading the data of step 1855
# Reading the data of step 1856
# Reading the data of step 1857
# Reading the data of step 1858
# Reading the data of step 1859
# Reading the data of step 1860
# Reading the data of step 1861
# Reading the data of step 1862
# Reading the data of step 1863
# Reading the data of step 1864
# Reading the data of step 1865
# Reading the data of step 1866
# Reading the data of step 1867
# Reading the data of step 1868
# Reading the data of step 1869
# Reading the data of step 1870
# Reading the data of step 1871
# Reading the data of step 1872
# Reading the data of step 1873
# Reading the data of step 1874
# Reading the data of step 1875
# Reading the data of step 1876
# Reading the data of step 1877
# Reading the data of step 1878
# Reading the data of step 1879
# Reading the data of step 1880
# Reading the data of step 1881
# Reading the data of step 1882
# Reading the data of step 1883
# Reading the data of step 1884
# Reading the data of step 1885
# Reading the data of step 1886
# Reading the data of step 1887
# Reading the data of step 1888
# Reading the data of step 1889
# Reading the data of step 1890
# Reading the data of step 1891
# Reading the data of step 1892
# Reading the data of step 1893
# Reading the data of step 1894
# Reading the data of step 1895
# Reading the data of step 1896
# Reading the data of step 1897
# Reading the data of step 1898
# Reading the data of step 1899
# Reading the data of step 1900
# Reading the data of step 1901
# Reading the data of step 1902
# Reading the data of step 1903
# Reading the data of step 1904
# Reading the data of step 1905
# Reading the data of step 1906
# Reading the data of step 1907
# Reading the data of step 1908
# Reading the data of step 1909
# Reading the data of step 1910
# Reading the data of step 1911
# Reading the data of step 1912
# Reading the data of step 1913
# Reading the data of step 1914
# Reading the data of step 1915
# Reading the data of step 1916
# Reading the data of step 1917
# Reading the data of step 1918
# Reading the data of step 1919
# Reading the data of step 1920
# Reading the data of step 1921
# Reading the data of step 1922
# Reading the data of step 1923
# Reading the data of step 1924
# Reading the data of step 1925
# Reading the data of step 1926
# Reading the data of step 1927
# Reading the data of step 1928
# Reading the data of step 1929
# Reading the data of step 1930
# Reading the data of step 1931
# Reading the data of step 1932
# Reading the data of step 1933
# Reading the data of step 1934
# Reading the data of step 1935
# Reading the data of step 1936
# Reading the data of step 1937
# Reading the data of step 1938
# Reading the data of step 1939
# Reading the data of step 1940
# Reading the data of step 1941
# Reading the data of step 1942
# Reading the data of step 1943
# Reading the data of step 1944
# Reading the data of step 1945
# Reading the data of step 1946
# Reading the data of step 1947
# Reading the data of step 1948
# Reading the data of step 1949
# Reading the data of step 1950
# Reading the data of step 1951
# Reading the data of step 1952
# Reading the data of step 1953
# Reading the data of step 1954
# Reading the data of step 1955
# Reading the data of step 1956
# Reading the data of step 1957
# Reading the data of step 1958
# Reading the data of step 1959
# Reading the data of step 1960
# Reading the data of step 1961
# Reading the data of step 1962
# Reading the data of step 1963
# Reading the data of step 1964
# Reading the data of step 1965
# Reading the data of step 1966
# Reading the data of step 1967
# Reading the data of step 1968
# Reading the data of step 1969
# Reading the data of step 1970
# Reading the data of step 1971
# Reading the data of step 1972
# Reading the data of step 1973
# Reading the data of step 1974
# Reading the data of step 1975
# Reading the data of step 1976
# Reading the data of step 1977
# Reading the data of step 1978
# Reading the data of step 1979
# Reading the data of step 1980
# Reading the data of step 1981
# Reading the data of step 1982
# Reading the data of step 1983
# Reading the data of step 1984
# Reading the data of step 1985
# Reading the data of step 1986
# Reading the data of step 1987
# Reading the data of step 1988
# Reading the data of step 1989
# Reading the data of step 1990
# Reading the data of step 1991
# Reading the data of step 1992
# Reading the data of step 1993
# Reading the data of step 1994
# Reading the data of step 1995
# Reading the data of step 1996
# {'model': 2, 'filename': None, 'nstates': 11, 'istep': 1200, 'HVIB': [<liblibra_core.CMATRIX object at 0x2b6f26b16bc8>, <liblibra_core.CMATRIX object at 0x2b6f26b166c0>, <liblibra_core.CMATRIX object at 0x2b6f26b16a78>, <liblibra_core.CMATRIX object at 0x2b6f26b169d0>, <liblibra_core.CMATRIX object at 0x2b6f26b16848>, <liblibra_core.CMATRIX object at 0x2b6f26b2c2d0>, <liblibra_core.CMATRIX object at 0x2b6f26b2c768>, <liblibra_core.CMATRIX object at 0x2b6f26b16a08>, <liblibra_core.CMATRIX object at 0x2b6f26b2cc70>, <liblibra_core.CMATRIX object at 0x2b6f26b2c378>, <liblibra_core.CMATRIX object at 0x2b6f26b2e068>, <liblibra_core.CMATRIX object at 0x2b6f26b168f0>, <liblibra_core.CMATRIX object at 0x2b6f26b2c308>, <liblibra_core.CMATRIX object at 0x2b6f26b2e538>, <liblibra_core.CMATRIX object at 0x2b6f26b2e500>, <liblibra_core.CMATRIX object at 0x2b6f26b3a538>, <liblibra_core.CMATRIX object at 0x2b6f26b3a960>, <liblibra_core.CMATRIX object at 0x2b6f26b3a068>, <liblibra_core.CMATRIX object at 0x2b6f26b30ab0>, <liblibra_core.CMATRIX object at 0x2b6f26b3a490>, <liblibra_core.CMATRIX object at 0x2b6f26b30ae8>, <liblibra_core.CMATRIX object at 0x2b6f26b307d8>, <liblibra_core.CMATRIX object at 0x2b6f26b325e0>, <liblibra_core.CMATRIX object at 0x2b6f26b325a8>, <liblibra_core.CMATRIX object at 0x2b6f26b321f0>, <liblibra_core.CMATRIX object at 0x2b6f26b32228>, <liblibra_core.CMATRIX object at 0x2b6f26b30ea0>, <liblibra_core.CMATRIX object at 0x2b6f26b32618>, <liblibra_core.CMATRIX object at 0x2b6f26b4d4c8>, <liblibra_core.CMATRIX object at 0x2b6f26b4db58>, <liblibra_core.CMATRIX object at 0x2b6f26b4d490>, <liblibra_core.CMATRIX object at 0x2b6f26b4d7d8>, <liblibra_core.CMATRIX object at 0x2b6f26b3b308>, <liblibra_core.CMATRIX object at 0x2b6f26b3b960>, <liblibra_core.CMATRIX object at 0x2b6f26b3bce0>, <liblibra_core.CMATRIX object at 0x2b6f26b39810>, <liblibra_core.CMATRIX object at 0x2b6f26b32ca8>, <liblibra_core.CMATRIX object at 0x2b6f26b4dc00>, <liblibra_core.CMATRIX object at 0x2b6f26b398b8>, <liblibra_core.CMATRIX object at 0x2b6f26b39bc8>, <liblibra_core.CMATRIX object at 0x2b6f26b39c00>, <liblibra_core.CMATRIX object at 0x2b6f26b36998>, <liblibra_core.CMATRIX object at 0x2b6f26b36730>, <liblibra_core.CMATRIX object at 0x2b6f26b4d458>, <liblibra_core.CMATRIX object at 0x2b6f26b39458>, <liblibra_core.CMATRIX object at 0x2b6f26b3d0a0>, <liblibra_core.CMATRIX object at 0x2b6f26b3d068>, <liblibra_core.CMATRIX object at 0x2b6f26b3d420>, <liblibra_core.CMATRIX object at 0x2b6f26b36810>, <liblibra_core.CMATRIX object at 0x2b6f26b3d880>, <liblibra_core.CMATRIX object at 0x2b6f26b2f928>, <liblibra_core.CMATRIX object at 0x2b6f26b2f5a8>, <liblibra_core.CMATRIX object at 0x2b6f26b2f228>, <liblibra_core.CMATRIX object at 0x2b6f26b2f5e0>, <liblibra_core.CMATRIX object at 0x2b6f26b33ae8>, <liblibra_core.CMATRIX object at 0x2b6f26b33458>, <liblibra_core.CMATRIX object at 0x2b6f26b33730>, <liblibra_core.CMATRIX object at 0x2b6f26b3d500>, <liblibra_core.CMATRIX object at 0x2b6f26b33b20>, <liblibra_core.CMATRIX object at 0x2b6f26b38a08>, <liblibra_core.CMATRIX object at 0x2b6f26b38688>, <liblibra_core.CMATRIX object at 0x2b6f26b38298>, <liblibra_core.CMATRIX object at 0x2b6f26b38378>, <liblibra_core.CMATRIX object at 0x2b6f26b45ae8>, <liblibra_core.CMATRIX object at 0x2b6f26b45458>, <liblibra_core.CMATRIX object at 0x2b6f26b45730>, <liblibra_core.CMATRIX object at 0x2b6f26b45228>, <liblibra_core.CMATRIX object at 0x2b6f26b2f1f0>, <liblibra_core.CMATRIX object at 0x2b6f26b45f80>, <liblibra_core.CMATRIX object at 0x2b6f26b3f730>, <liblibra_core.CMATRIX object at 0x2b6f26b3f2d0>, <liblibra_core.CMATRIX object at 0x2b6f26b3fa40>, <liblibra_core.CMATRIX object at 0x2b6f26b3f6c0>, <liblibra_core.CMATRIX object at 0x2b6f26b3c730>, <liblibra_core.CMATRIX object at 0x2b6f26b3cb20>, <liblibra_core.CMATRIX object at 0x2b6f26b38ea0>, <liblibra_core.CMATRIX object at 0x2b6f26b3cf48>, <liblibra_core.CMATRIX object at 0x2b6f26b31650>, <liblibra_core.CMATRIX object  ...
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
#  keywords = ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
#
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw']) step= 0
# In mem_saver.save_data_txt()
#  data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords = ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
#  keys = dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
#  step= 79
#  step= 79
# In mem_saver.save_data_txt()
# data_name =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
#  step= 79
#  step= 79
# In mem_saver.save_data_txt()
#  step= 79data_name =
#  ['timestep', 'time', 'SH_pop', 'SH_pop_raw']
# keywords =  ['timestep', 'time', 'SH_pop', 'SH_pop_raw', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC']
# keys =  dict_keys(['timestep', 'time', 'Ekin_ave', 'Epot_ave', 'Etot_ave', 'dEkin_ave', 'dEpot_ave', 'dEtot_ave', 'Etherm', 'E_NHC', 'SH_pop', 'SH_pop_raw'])
#  step= 0
#  step= 79
#  step= 158
#  step= 158
#  step= 79
#  step= 158
#  step= 158
#  step= 158
#  step= 79
#  step= 158
#  step= 237
#  step= 237
#  step= 158
#  step= 237
#  step= 237
#  step= 237
#  step= 158
#  step= 237
#  step= 316
#  step= 316
#  step= 237
#  step= 316
#  step= 316
#  step= 316
#  step= 237
#  step= 316
#  step= 395
#  step= 395
#  step= 316
#  step= 395
#  step= 395
#  step= 395
#  step= 316
#  step= 395
#  step= 474
#  step= 474
#  step= 395
#  step= 474
#  step= 474
#  step= 474
#  step= 395
#  step= 474
#  step= 553
#  step= 553
#  step= 474
#  step= 553
#  step= 553
#  step= 553
#  step= 474
#  step= 553
#  step= 632
#  step= 632
#  step= 553
#  step= 632
#  step= 632
#  step= 632
#  step= 553
#  step= 632
#  step= 711
#  step= 711
#  step= 632
#  step= 711
#  step= 711
#  step= 711
#  step= 632
#  step= 711
#  step= 790
# Calculation time = 123.58220219612122 seconds
#  step= 790
#  step= 711
# Calculation time = 125.8735580444336 seconds
#  step= 790
# Calculation time = 126.1305365562439 seconds
#  step= 790
# Calculation time = 126.34325647354126 seconds
#  step= 790
#  step= 711
# Calculation time = 126.32068586349487 seconds
#  step= 790
# Calculation time = 125.2770676612854 seconds
#  step= 790
# Calculation time = 122.94501876831055 seconds
#  step= 790
# Calculation time = 119.93651747703552 seconds
# Total time 137.21975350379944
# ======= Running initial state 10 =======
#     *** Running decoherence method 0 ( FSSH ) ***
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  4.009385446576062e-05  1/B =  24941.478272037442
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  6.98719294577206e-05  1/B =  14311.899038155208
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  2.6687855626739447e-05  1/B =  37470.226682359105
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  4.963297273704437e-05  1/B =  20147.89654647532
# Number of samples = 4
# Lifetime from averaging individual lifetimes 24217.875134756767 +/- 9649.251911148707
# Average rates  4.6571653071816256e-05 +/- 1.7799003724630796e-05
# Lifetime 21472.289129568595 +/- 8206.39442633029
#     *** Running decoherence method 1 ( IDA ) ***
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  3.058698984767903e-05  1/B =  32693.63886344903
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  2.6366098546869705e-05  1/B =  37927.492314509465
# raw data lengths: 797 797
# raw data lengths: 797 797
# Fitting parameters : A =  1.0  and B =  2.5752334203021956e-05  1/B =  38831.431439044194
# Number of samples = 3
# Lifetime from averaging individual lifetimes 36484.1875390009 +/- 3749.781199416713
# Average rates  2.756847419919023e-05 +/- 2.9784593648290995e-06
# Lifetime 36273.316860944484 +/- 3918.918381818417

# %% [markdown]
# ## 5. Decoherence times <a name="deco_times"></a>
# [Back to TOC](#toc)
#
# We have computed the average decoherence times between pairs of states when we ran the dynamics in the last cell in `average_decoherence.txt` file. Now, we load and plot it using `plt.imshow`.

# %%
# %matplotlib inline
#notebook
figure = plt.figure(num=None, figsize=(2.41, 2.41), dpi=300, edgecolor='black', frameon=True)        

avg_deco = np.loadtxt('average_decoherence_mb.txt')
plt.imshow(np.flipud(avg_deco), extent=(0,avg_deco.shape[0],0,avg_deco.shape[1]), cmap='hot')
plt.colorbar().ax.set_title('fs')
plt.title('LiAlH$_4$ unit cell')
plt.xlabel('State_index')
plt.ylabel('State index')
# Out:
# Text(0, 0.5, 'State index')

# %% [markdown]
# ## 6. Fitting data <a name="fit_data"></a>
# [Back to TOC](#toc)
#
#
# After the dynamic is done, we load all the NA-MD results, stored in `SH_pop.txt` files, using `np.loadtxt` and start fitting them to a stretched-compressed exponential function of the form:
#
# $$P(t; E_0)=\exp(-(\frac{t}{\tau})^\beta)$$
#
#
# Then, the average time scale is computed for the fits that has an $R^2$ value more than $0.01$. The error bars are computed using the following formula:
#
# $$\epsilon=Z\frac{s}{\sqrt{N}}$$
#
# where $s$ is the stadard deviaton and $N$ is the number of samples (the ones that have $R^2$ value of more than $0.01$). The $Z$ value is the confidence interval coefficient which for confidence interval of $95\%$, a value of $1.96$ is chosen.
#
# In the above, we have only considered, FSSH and IDA ad for simplicity, we will consider the decay dynamics of the hot state which is the 10th state. Also, please note that this is just an example and we want to show how the workflow is. So, we consider even lower $R^2$ value. For better and more accurate results, we need not only longer trajectory but also larger number of surface hopping trajectory.

# %%
# %matplotlib inline
#notebook
figure = plt.figure(num=None, figsize=(3.21, 2.41), dpi=300, edgecolor='black', frameon=True)        

def stretched_compressed(t, tau, beta):
    return np.exp( -np.power(( t/tau ),beta) )

for c, scheme in enumerate(['FSSH', 'IDA']):
    
    print(F'------------{scheme}----------')
    plt.subplot(1,2,c+1)
    folders = glob.glob(F'./namd_regular/_start_s10_{scheme}_batch*', recursive = True)
    taus = []
    betas = []
    
    for folder in folders:
        
        print("Folder =", folder)
        sh_pop = np.loadtxt(folder+'/SH_pop.txt')
        sh_pop_hot_state = sh_pop[:,10]
        md_time = np.arange(0, sh_pop_hot_state.shape[0], 1.0)
        popt, pcov = curve_fit( stretched_compressed, md_time, sh_pop_hot_state, 
                                   bounds=([0.0, 0.0],[np.inf, np.inf]))
        tau, beta = popt
        # Computing the R-squared
        residuals  = sh_pop_hot_state - stretched_compressed(md_time, *popt)
        ss_res     = np.sum(residuals**2)
        ss_tot     = np.sum((sh_pop_hot_state - np.mean(sh_pop_hot_state))**2)
        r_squared  = 1.0 - (ss_res / ss_tot)
        print('tau:', tau, ' beta:', beta,' R2:', r_squared)
        
        if r_squared>0.01:
            taus.append(tau)
            betas.append(beta)
            plt.plot(md_time, sh_pop_hot_state, color='gray')
            
    ave_tau = np.average(np.array(taus))
    ave_beta = np.average(np.array(betas))
    # Compute the erro bars
    # The confidence interval
    Z = 1.96
    N = len(taus)
    s = np.std(np.array(taus))
    error_bar = Z*s/np.sqrt(N)
    print(F'The timescales: {ave_tau}+-{error_bar} average over {len(taus)} samples')
    
    # Plot average fit
    
    plt.plot(md_time, stretched_compressed(md_time, ave_tau-error_bar, ave_beta), ls='--', color='red')
    plt.plot(md_time, stretched_compressed(md_time, ave_tau,           ave_beta), ls='-',  color='red')
    plt.plot(md_time, stretched_compressed(md_time, ave_tau+error_bar, ave_beta), ls='--', color='red')
    
    plt.title(scheme)
    plt.xlabel('Time, fs')
    plt.ylabel('Population')
    plt.tight_layout()
# Out:
# ------------FSSH----------
# Folder = ./namd_regular/_start_s10_FSSH_batch0
# tau: 543.8566071607729  beta: 1.1666445718162672  R2: 0.9925969339573597
# Folder = ./namd_regular/_start_s10_FSSH_batch1
# tau: 459.2064545927618  beta: 0.8243575992245821  R2: 0.993969746127366
# Folder = ./namd_regular/_start_s10_FSSH_batch2
# tau: 433.1105158729852  beta: 1.064911535083876  R2: 0.9902176470797883
# Folder = ./namd_regular/_start_s10_FSSH_batch3
# tau: 462.04359132995705  beta: 0.889796131985089  R2: 0.9910724617421798
# The timescales: 474.55429223911926+-40.739223577230085 average over 4 samples
# ------------IDA----------
# Folder = ./namd_regular/_start_s10_IDA_batch0
# tau: 422.26330101772777  beta: 0.8885544803995243  R2: 0.9927656634677541
# Folder = ./namd_regular/_start_s10_IDA_batch1
# tau: 338.14089922486033  beta: 0.9778539495923333  R2: 0.9970721709145602
# Folder = ./namd_regular/_start_s10_IDA_batch2
# tau: 417.31820612318705  beta: 0.8707919928852579  R2: 0.9959269482480498
# Folder = ./namd_regular/_start_s10_IDA_batch3
# tau: 503.8397254388042  beta: 0.8168586049946086  R2: 0.9919387191065916
# The timescales: 420.39053295114485+-57.4402830268043 average over 4 samples
